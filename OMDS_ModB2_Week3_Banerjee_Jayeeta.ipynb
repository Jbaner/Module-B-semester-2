# %% [markdown]
# <a href="https://colab.research.google.com/github/Jbaner/Module-B-semester-2/blob/main/OMDS_ModB2_Week3_Banerjee_Jayeeta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 - Univariate Analysis
#
# ## Please run the cells of the notebook as you get to them while reading

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
import seaborn as sns

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are a *histogram* and table representation of the same data.  A species of bird is being analyzed, and each individual's body length in inches has been measured.
#
# Please write a short explanation of the pros and cons of these two representations.  Which would you choose?  How would you modify the formatting, if at all, to make it more visually interesting, clear, or informative?

# %%
import numpy as np
import pandas as pd

np.random.seed(0)
num_data = 10000
data = np.random.normal(size = num_data) + 6
df = pd.DataFrame(data.T, columns = ["data"])
df

# %%
histnums = np.histogram(df["data"])
histcounts = histnums[0]
histmins = histnums[1][0:-1]
histmaxes = histnums[1][1:]

# %%
pd.DataFrame(np.array([histcounts, histmins, histmaxes]).T, columns = ["count", "minval", "maxval"])
# Out:
#     count    minval    maxval
# 0    10.0  2.259899  3.014075
# 1   110.0  3.014075  3.768252
# 2   579.0  3.768252  4.522428
# 3  1710.0  4.522428  5.276604
# 4  2833.0  5.276604  6.030780
# 5  2688.0  6.030780  6.784956
# 6  1479.0  6.784956  7.539132
# 7   487.0  7.539132  8.293308
# 8    97.0  8.293308  9.047484
# 9     7.0  9.047484  9.801660

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Table representation:
#   **Pros:** Represnts exact counts by range of data. We can do statistical analysis and it is easy to compare the data.
#   **Cons:** Hard to explore overall distribution due to it's non-visual approach. Less intuitive and not presentable to non technical audiences.
#
# Histogram:
#   **Pros:** Visual representation of the distribution and easy to understand the data. Shape, variability, spread, center and outliers are easily visible. Center section indicates where birds with similar length mostly cluster. Very useful for creating reports.
#   **Cons:** Hard to understand when exact data/counts are required to report. Bin width selection will also change the appearance.
#
#   **Which would I choose?** I would choose the histogram to analyze bird's body length because it will be useful to represent the insights quickly. The length is a continuous metrics. Based on the histogram I can determine the distribution of shape such as normal, any subgroup, very large or very small bird. Additionally to make it more meaningful I will add small notes in the visual.
#
#   **Modification**:
#       **Histogram:** Adding Meaningful title, labels and notes. Increase the bins for smoother shape. Add edge color for more clarity.
#       **Table representation** Round the data upto 1 or 2 decimal point and add a percentage field to make it more informative.

# %%
#After modification:
import matplotlib.pyplot as plt
ax=df.plot.hist(edgecolor="black")
plt.xlabel("Length")
plt.title("Histogram of bird's body length ")
# Out:
# Text(0.5, 1.0, "Histogram of bird's body length ")

# %%
#after modification
pd.DataFrame(np.array([histcounts, histmins, histmaxes]).T, columns = ["count", "minval", "maxval"]).round(2)
# Out:
#     count  minval  maxval
# 0    10.0    2.26    3.01
# 1   110.0    3.01    3.77
# 2   579.0    3.77    4.52
# 3  1710.0    4.52    5.28
# 4  2833.0    5.28    6.03
# 5  2688.0    6.03    6.78
# 6  1479.0    6.78    7.54
# 7   487.0    7.54    8.29
# 8    97.0    8.29    9.05
# 9     7.0    9.05    9.80

# %% [markdown]
# # 3. Homework - Amusement Park Rides

# %% [markdown]
# Now let's imagine we have some data about how many times different visitors to an amusement park used each ride, as well as how much money they spend at the amusement park.  Each sample represents a single visit by a single visitor on a given date.

# %%
num_visits = 10000
np.random.seed(0)

# %%
df = pd.DataFrame(columns = ["VisitDate"])

# %%
start = datetime(2010, 1, 1)
end = datetime(2024, 1, 1)
numdays = (end - start).days
random_days = np.random.randint(0, numdays, size = num_visits)
s = start + pd.to_timedelta(random_days, unit='D')
s = s.sort_values()
df["VisitDate"] = s

# %%
df["IsAdult"] = np.random.choice([True, True, False], size = num_visits)

# %%
df["MartianRide"] = np.random.choice([0] * 8 + [1] * 3 + [2] * 3 + [3] * 1 + [10], size = num_visits) * df["IsAdult"]

# %%
df["TeacupRide"] = np.random.choice([0] * 2 + [1] * 5 + [2] * 3 + [5] * 2, size = num_visits) * ~df["IsAdult"]

# %%
df["RiverRide"] = np.random.choice([0] * 8 + [1] * 3 + [2] * 2, size = num_visits) * df["IsAdult"] + np.random.randint(1, 5, size = num_visits) * ~df["IsAdult"]

# %%
df["MoneySpent"] = np.round(np.random.random(size = num_visits)**2 * 100, 2)

# %%
df.iloc[0:10]

# %% [markdown]
# 1. Find the mean, median, and mode for how many times visitors rode each ride.  See Week 1 for Google advice on this.

# %%
print("MartianRide")
#Mean
print("Mean")
print(df["MartianRide"].mean())
#median
print("median")
print(df["MartianRide"].median())
#mode
print("mode")
print(df["MartianRide"].mode()[0])
print(".....................................")

print("TeacupRide")
#Mean
print("Mean")
print(df["TeacupRide"].mean())
#median
print("median")
print(df["TeacupRide"].median())
#mode
print("mode")
print(df["TeacupRide"].mode()[0])
print(".....................................")

print("RiverRide")
#Mean
print("Mean")
print(df["RiverRide"].mean())
#median
print("median")
print(df["RiverRide"].median())
#mode
print("mode")
print(df["RiverRide"].mode()[0])
# Out:
# MartianRide
# Mean
# 0.9073
# median
# 0.0
# mode
# 0
# .....................................
# TeacupRide
# Mean
# 0.5862
# median
# 0.0
# mode
# 0
# .....................................
# RiverRide
# Mean
# 1.2007
# median
# 1.0
# mode
# 0

# %% [markdown]
# 2. Use groupby() to find the mean, median, and mode for how many times each ride was ridden on each given day.

# %% [markdown]
# Suggested Google search or ChatGPT prompt:
# I first tried: "How do I use groupby to find the mean over each day in my DataFrame?" but Google didn't help me.
#
# Then I tried: "How do I find the mean over each date in a dataframe?"  Sometimes, you have to try multiple searches.
#
# This gives me a very helpful site, where someone is doing the same thing we are:
#
# https://stackoverflow.com/questions/40788530/how-to-calculate-mean-of-some-rows-for-each-given-date-in-a-dataframe

# %%
rides=["MartianRide","TeacupRide","RiverRide"] #list of rides
#using group by to analyse the ride by each given day
mean_by_day=df.groupby("VisitDate")[rides].mean()
median_by_day=df.groupby("VisitDate")[rides].median()
mode_by_day=(df.groupby("VisitDate")[rides].agg(lambda x: x.mode().iloc[0]))

#Mean
print("Mean per day")
print(mean_by_day)
print(".................................................")

#Median
print("Median per day")
print(median_by_day)
print(".................................................")

#Mode
print("Mode per day")
print(mode_by_day)
print("..................................................")
# Out:
# Mean per day
#             MartianRide  TeacupRide  RiverRide
# VisitDate
# 2010-01-01         0.75        0.25       1.25
# 2010-01-02         0.00        1.00       2.00
# 2010-01-03         0.00        1.50       1.25
# 2010-01-04         0.00        0.00       1.00
# 2010-01-05         0.50        0.00       0.00
# ...                 ...         ...        ...
# 2023-12-27         0.50        0.50       1.00
# 2023-12-28         6.00        0.00       0.00
# 2023-12-29         0.00        1.00       3.00
# 2023-12-30         3.00        0.00       1.00
# 2023-12-31         0.00        0.00       1.00
#
# [4404 rows x 3 columns]
# .................................................
# Median per day
#             MartianRide  TeacupRide  RiverRide
# VisitDate
# 2010-01-01          0.0         0.0        0.5
# 2010-01-02          0.0         1.0        2.0
# 2010-01-03          0.0         0.5        0.5
# 2010-01-04          0.0         0.0        1.0
# 2010-01-05          0.5         0.0        0.0
# ...                 ...         ...        ...
# 2023-12-27          0.5         0.5        1.0
# 2023-12-28          6.0         0.0        0.0
# 2023-12-29          0.0         1.0        3.0
# 2023-12-30          3.0         0.0        1.0
# 2023-12-31          0.0         0.0        1.0
#
# [4404 rows x 3 columns]
# .................................................
# Mode per day
#             MartianRide  TeacupRide  RiverRide
# VisitDate
# 2010-01-01            0           0          0
# 2010-01-02            0           1          2
# 2010-01-03            0           0          0
# 2010-01-04            0           0          1
# 2010-01-05            0           0          0
# ...                 ...         ...        ...
# 2023-12-27            0           0          0
# 2023-12-28            2           0          0
# 2023-12-29            0           1          3
# 2023-12-30            3           0          1
# 2023-12-31            0           0          1
#
# [4404 rows x 3 columns]
# ..................................................

# %% [markdown]
# 3. Find the standard deviation and variance of the count for each ride.
#
# Suggested Google search or ChatGPT prompt: "How do I find the standard deviation of a Series in pandas documentation?" and similar query for variance.
#
# I included the word "documentation" because this task likely involves applying one single function for standard deviation and another for variance, so I expected that I could find a single documentation page for each that would cover my needs.  I get these:
#
# https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.Series.var.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.std.html

# %%
rides=["MartianRide","TeacupRide","RiverRide"] #list of rides
# standard deviation
std_dev=df[rides].std()
#variance
variance=df[rides].var()

#standard deviation
print("standard deviation of each ride")
print(std_dev)
print(".................................................")

#variance
print("variance of each ride")
print(variance)
# Out:
# standard deviation of each ride
# MartianRide    2.077339
# TeacupRide     1.232851
# RiverRide      1.295757
# dtype: float64
# .................................................
# variance of each ride
# MartianRide    4.315338
# TeacupRide     1.519922
# RiverRide      1.678987
# dtype: float64

# %% [markdown]
# 4. Find the 90th percentile count for each ride.  That is, if the customers are ordered by their number of rides, and there are 100 customers, how many rides does the 90th person take?  There is a function in pandas that easily does this calculation.
#
# Suggested Google search or ChatGPT prompt: "How do I find a percentile value for a Series in pandas documentation?"
#
# This time, I will let you find the page!  Hint: it's not actually called the "percentile" function.

# %%
rides=["MartianRide","TeacupRide","RiverRide"] #list of rides
#90th percentile
P_90= df[rides].quantile(0.9)
print("90th percentile count for each ride")
print(P_90)
# Out:
# 90th percentile count for each ride
# MartianRide    2.0
# TeacupRide     2.0
# RiverRide      3.0
# Name: 0.9, dtype: float64

# %% [markdown]
# 5. Plot a histogram of the ride count, using each day as data element as you did in #2.  Use both the total ride count for each day as well as, separately, the mean ride count for each day.
#
# Suggested Google search or ChatGPT prompt: "How do I plot a histogram for a Series in pandas?"
#
# I found this: https://pandas.pydata.org/docs/reference/api/pandas.Series.plot.hist.html
#
# Note: the "by" keyword will not help you plot a count for each day; if you try to use it for this, it will try to draw a separate histogram for each day.
#
# You've already learned how to find the mean ride count for each day.  Can you use a similar idea to find the total ride count for each day?

# %%
import matplotlib.pyplot as plt

df['TotalRide']=(df["MartianRide"]+df["TeacupRide"]+df["RiverRide"])
ride_by_day=df.groupby("VisitDate")['TotalRide']
#total rides count by day
total_ride_by_day=ride_by_day.sum()
#mean ride count by day
mean_ride_by_day=ride_by_day.mean()

#Histogram of the ride count, using each day as data element
plt.figure(figsize=(10,5))
total_ride_by_day.plot.hist(bins=20, alpha=0.5, color="blue", edgecolor="black")
plt.title("Histogram of the ride count")
plt.xlabel("Total rides per day")
plt.ylabel("Frequency")
plt.show()

#Histogram of the mean ride, using each day as data element
plt.figure(figsize=(10,5))
mean_ride_by_day.plot.hist(bins=20, alpha=0.5, color="green", edgecolor="black")
plt.title("Histogram of the mean ride")
plt.xlabel("Mean rides per day")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 6. Make a bar chart showing the total number of Adult and Child participants.
#
# Try to formulate your own Google search or ChatGPT prompt.
#
# Here's one page I found:
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
#
# which shows some interesting examples for you to use.  I recommend clicking on the first, basic example to see how to use the function.
#
# You can also look up the pandas documentation, which might lead to an entirely different method.

# %%
check_riders=df["IsAdult"].value_counts()
print(check_riders)
check_riders.index=["Adult","Child"]
check_riders.plot(kind='bar', color=["skyblue","orange"], edgecolor="black")
plt.title("Total number of Adult and Child participants")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()
# Out:
# IsAdult
# True     6625
# False    3375
# Name: count, dtype: int64

# %% [markdown]
# 7. Make a stacked bar chart showing how many Adult and Child visits took the River Ride, with the x-axis showing the number of rides and with two stacked bars (adult, child).  That is, there could be a column for the number of Adults (and Children) who took 0 rides, 1 ride, 2 rides, and so on.
#
# Try to formulate your own Google search or ChatGPT prompt.
#
# For me, the pandas documentation was easier than the matplotlib documentation.
#
# * If you use the pandas method, you might have to one-hot encode the IsAdult column.  You might want names for the new columns other than True and False.  Use df.join or pd.concat to attach the pd.get_dummies table you've created, and then groupby the RiverRide value.
#
# * You will need to end up with a small table with two columns (IsAdult True and False) and an index (RiverRide) as well as a small number of rows (the values of RiverRide)
#
# * That said, if you can come up with another approach, it's fine.

# %%
hot_encode=pd.get_dummies(df["IsAdult"])
hot_encode.columns=["Child","Adult"]
df1=df.join(hot_encode)
#df1

RiverRide_count=df1.groupby("RiverRide")[["Adult","Child"]].sum()
#print(RiverRide_count)
RiverRide_count.plot(kind='bar', stacked=True, color=["teal","orange"], edgecolor="black")
plt.title("Total number of Adult and Child took the River Ride")
plt.xlabel("Count of River Rides")
plt.ylabel("Number of participants")
plt.tight_layout()
plt.show()

# %% [markdown]
# 8. Other tasks
#
# Use seaborn (import seaborn as sns) to create a kernel density estimation (kde) plot.  (You can choose any aspect of the amusement park dataset to plot.)  Here is a tutorial you can read about seaborn:
#
# https://seaborn.pydata.org/tutorial/introduction.html
#
# Seaborn often makes nicer looking graphs than pandas or matplotlib.
#
# Now use seaborn to make a swarm plot, a violin plot, and a box plot.
#
# Which plots are the best for showing this data?
# Answer:Violin plot and Kde plot are very useful to show the money spent.

# %%
import seaborn as sns
sns.kdeplot(data=df,x="MoneySpent")
plt.title("Kde plot on money spent")
# Out:
# Text(0.5, 1.0, 'Kde plot on money spent')

# %%
sns.swarmplot(df["MoneySpent"])
plt.title("Swarm plot on money spent")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Swarm plot on money spent')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 70.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(df["MoneySpent"])
plt.title("Violin plot on money spent")
# Out:
# Text(0.5, 1.0, 'Violin plot on money spent')

# %%
sns.boxplot(df["MoneySpent"])
plt.title("Box plot on money spent")
# Out:
# Text(0.5, 1.0, 'Box plot on money spent')

# %% [markdown]
# # 4. Storytelling With Data graph
#
# Try to make a scatterplot using amusement park dataset that is similar to the one on page 45, where the two axes are the Teacup Ride count and the River Ride count.  If you want to see individual dots and not a dense swarm of dots, you'll have to cut the dataset down to a small number of points (say, 100 points or so).  You can remove the other points, for instance, and focus on the first 100 points.
#
# Here are some things you could do (you don't have to do all of them):
#
# * Draw a dashed line that roughly separates the adult from child points.
#
# * Draw the points in the adult vs. child region of the graph in different colors.
#
# * Choose the right size and number of dots to make the graph look good.
#
# * Write a word that appears on the dashed line (like AVG in the plot on page 45).
#
# If there are any other graphs in the Storytelling With Data chapter that look interesting, and you want more practice, you can try to reproduce them too.

# %%
#generating new dataset for clear adult kids visual
num_visits=10000
df1.loc[~df1["IsAdult"], "TeacupRide"]=np.random.randint(3,10, size=(~df1["IsAdult"]).sum())
df1.loc[~df1["IsAdult"], "RiverRide"]=np.random.randint(3,10, size=(~df1["IsAdult"]).sum())
df1["TeacupRide"] +=np.random.normal(0,0.3,num_visits)
df1["RiverRide"] +=np.random.normal(0,0.3,num_visits)

from matplotlib.lines import lineStyles
df2=df1.sample(n=1000,random_state=1)
plt.figure(figsize=(6,6))
#scatter plot
sns.scatterplot(data=df2, x="TeacupRide", y="RiverRide", s=40, hue="IsAdult",alpha=0.35)
#Adding dash line to separate Adult vs Child
plt.axvline(x=2,color="gray",linestyle="--", linewidth=2)
#Adding text on the dashed line
x_text= 1.5
y_text= 0*x_text+ 4
plt.text(x_text, y_text, "Adult vs Child Partition", color="gray", fontsize=13, rotation=90)
#to remove right and top spines
ax=plt.gca()
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
plt.title("Scatter plot of TeacupRide vs RiverRide\n", loc="left")
plt.legend(title="IsAdult", loc="upper right")
plt.tight_layout()
plt.show()
